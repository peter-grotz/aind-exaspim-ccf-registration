# %%
# !grep -R "aws s3\|aws " -n .
# Out:
# Binary file ./data/exaSPIM_template_25um/exaspim_template_8sujects_nomask_25um_round6.nii.gz matches
# Binary file ./data/reg_exaspim_template_to_ccf_withGradMap_25um_v1.0/1InverseWarp.nii.gz matches
# Binary file ./data/reg_exaspim_template_to_ccf_withGradMap_25um_v2/moved_exaspim_to_ccf_25um.nii.gz matches
# Binary file ./data/exaspim_template_7subjects_nomask_10um_round6_template_only/fixed_median.nii.gz matches
# Binary file ./data/allen_mouse_ccf/ara_nissl/ara_nissl_10.nii.gz matches
# Binary file ./data/reg_exaspim_template_to_ccf_25um_v1.3/1Warp.nii.gz matches
# Binary file ./data/reg_exaspim_template_to_ccf_25um_v1.3/1InverseWarp.nii.gz matches
# Binary file ./data/reg_721332_to_ccf_25um_v1.3/ccf_alignment/ccf_aligned.zarr/0/0/0/10/0/9 matches
# Binary file ./data/reg_721332_to_ccf_25um_v1.3/ccf_alignment/721332_to_exaSPIM_SyN_1Warp.nii.gz matches
# ...
